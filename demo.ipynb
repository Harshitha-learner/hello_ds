# %%
import pandas as pd
import numpy as np
data = pd.read_csv('titanic3.csv')

# %%
data.replace('',np.nan, inplace=True)
data.astype({"age":np.float64, "fare":np.float64})
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs  = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
data.replace({"male":1, "female":0}, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5036\1397381805.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data.replace({"male":1, "female":0}, inplace=True)

# %%
data
# Out:
#       pclass  survived                                             name  sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton    0
# 1          1         1                   Allison, Master. Hudson Trevor    1
# 2          1         0                     Allison, Miss. Helen Loraine    0
# 3          1         0             Allison, Mr. Hudson Joshua Creighton    1
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0
# ...      ...       ...                                              ...  ...
# 1304       3         0                             Zabour, Miss. Hileni    0
# 1305       3         0                            Zabour, Miss. Thamine    0
# 1306       3         0                        Zakarian, Mr. Mapriededer    1
# 1307       3         0                              Zakarian, Mr. Ortin    1
# 1308       3         0                               Zimmerman, Mr. Leo    1
#
#         age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0     29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1      0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2      2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3     30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4     25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# ...     ...    ...    ...     ...       ...      ...      ...  ...    ...
# 1304  14.50      1      0    2665   14.4542      NaN        C  NaN  328.0
# 1305    NaN      1      0    2665   14.4542      NaN        C  NaN    NaN
# 1306  26.50      0      0    2656    7.2250      NaN        C  NaN  304.0
# 1307  27.00      0      0    2670    7.2250      NaN        C  NaN    NaN
# 1308  29.00      0      0  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# 1305                              NaN
# 1306                              NaN
# 1307                              NaN
# 1308                              NaN
#
# [1309 rows x 14 columns]

# %%
data.corr(numeric_only=True).abs()[['survived']]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply(lambda row: int((row['sibsp']+row['parch'])>0),axis=1)
data.corr(numeric_only=True).abs()[['survived']]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
data = data[['pclass','survived','sex','age','fare','relatives']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 1s 2ms/step - loss: 0.6922 - accuracy: 0.5897
# Epoch 2/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6896 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6846 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6751 - accuracy: 0.5861
# Epoch 5/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6598 - accuracy: 0.5861
# Epoch 6/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6376 - accuracy: 0.6136
# Epoch 7/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6119 - accuracy: 0.7273
# Epoch 8/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5877 - accuracy: 0.7584
# Epoch 9/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5680 - accuracy: 0.7620
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5524 - accuracy: 0.7691
# Epoch 11/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5398 - accuracy: 0.7751
# Epoch 12/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5291 - accuracy: 0.7835
# Epoch 13/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5201 - accuracy: 0.7811
# Epoch 14/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5110 - accuracy: 0.7751
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.7835
# Epoch 16/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4966 - accuracy: 0.7847
# Epoch 17/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4907 - accuracy: 0.7811
# Epoch 18/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4858 - accuracy: 0.7799
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4813 - accuracy: 0.7811
# Epoch 20/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4788 - accuracy: 0.7847
# Epoch 21/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4748 - accuracy: 0.7811
# Epoch 22/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4719 - accuracy: 0.7811
# Epoch 23/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4694 - accuracy: 0.7811
# Epoch 24/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4669 - accuracy: 0.7847
# Epoch 25/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.7883
# Epoch 26/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4632 - accuracy: 0.7895
# Epoch 27/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4618 - accuracy: 0.7847
# Epoch 28/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4600 - accuracy: 0.7859
# Epoch 29/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4593 - accuracy: 0.7859
# Epoch 30/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4583 - accuracy: 0.7859
# Epoch 31/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4573 - accuracy: 0.7835
# Epoch 32/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.7847
# Epoch 33/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4553 - accuracy: 0.7871
# Epoch 34/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4550 - accuracy: 0.7871
# Epoch 35/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4542 - accuracy: 0.7859
# Epoch 36/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4531 - accuracy: 0.7871
# Epoch 37/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4526 - accuracy: 0.7895
# Epoch 38/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4520 - accuracy: 0.7883
# Epoch 39/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4515 - accuracy: 0.7955
# Epoch 40/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.7990
# Epoch 41/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.7919
# Epoch 42/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4501 - accuracy: 0.7943
# Epoch 43/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4495 - accuracy: 0.7955
# Epoch 44/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4490 - accuracy: 0.7990
# Epoch 45/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4486 - accuracy: 0.7943
# Epoch 46/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.7919
# Epoch 47/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4479 - accuracy: 0.7955
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7931
# Epoch 49/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4479 - accuracy: 0.7967
# Epoch 50/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4471 - accuracy: 0.7943

# %%
y_pred = np.rint(model.predict(X_test).flatten())
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 7/7 [==============================] - 0s 2ms/step
# 0.7894736842105263
