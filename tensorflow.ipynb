# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (1.1.2)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (24.2)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow)
#   Downloading protobuf-3.19.6-cp310-cp310-win_amd64.whl.metadata (806 bytes)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (1.17.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (1.48.2)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.45.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2025.4.26)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\hp\anaconda3\envs\myenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (3.0.2)
# Downloading protobuf-3.19.6-cp310-cp310-win_amd64.whl (895 kB)
#    ---------------------------------------- 0.0/895.7 kB ? eta -:--:--
#    --------------------------------------- 895.7/895.7 kB 13.5 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    ------- -------------------------------- 5.2/26.4 MB 26.6 MB/s eta 0:00:01
#    --------------- ------------------------ 10.0/26.4 MB 25.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 18.9/26.4 MB 30.6 MB/s eta 0:00:01
#    ---------------------------------------  26.2/26.4 MB 34.6 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 28.9 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 39.5 MB/s eta 0:00:00
# Installing collected packages: libclang, tensorflow-io-gcs-filesystem, protobuf
#
#    ---------------------------------------- 0/3 [libclang]
#    ---------------------------------------- 0/3 [libclang]
#    ------------- -------------------------- 1/3 [tensorflow-io-gcs-filesystem]
#   Attempting uninstall: protobuf
#    ------------- -------------------------- 1/3 [tensorflow-io-gcs-filesystem]
#     Found existing installation: protobuf 3.20.3
#    ------------- -------------------------- 1/3 [tensorflow-io-gcs-filesystem]
#     Uninstalling protobuf-3.20.3:
#    ------------- -------------------------- 1/3 [tensorflow-io-gcs-filesystem]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#       Successfully uninstalled protobuf-3.20.3
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    -------------------------- ------------- 2/3 [protobuf]
#    ---------------------------------------- 3/3 [protobuf]
#
# Successfully installed libclang-18.1.1 protobuf-3.19.6 tensorflow-io-gcs-filesystem-0.31.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Preprocess the data: flatten the images and normalize the pixel values
train_images = train_images.reshape((train_images.shape[0], 28 * 28)).astype('float32') / 255
test_images = test_images.reshape((test_images.shape[0], 28 * 28)).astype('float32') / 255

# Build the model
model = Sequential([
    Dense(128, activation='relu', input_shape=(28 * 28,)),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_images, train_labels, epochs=5)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2587 - accuracy: 0.9258
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1135 - accuracy: 0.9670
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0776 - accuracy: 0.9766
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0572 - accuracy: 0.9823
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0449 - accuracy: 0.9855
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0723 - accuracy: 0.9781
# Test accuracy: 0.9781000018119812
